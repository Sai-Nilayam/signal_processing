# %%
# This file is dedicated to name entity pronounciation task. The idea is to record all the syllables of 
# Devnagari and then play them very smoothly to mimic the pronouciation of the name entity given a true 
# spelling.

# %%
# Now let's write all the devnagari syllables.

# ankush, sai, hasibul, sangarsh, nehal, muskan

# a aa i u e o - 6

# k kh g gh - 4
# ch chh j jh - 4
# t th d dh n - 5
# p ph b bh m - 5

# y r l w s sh h - 7

# total - 

# So let's say this much syllable is enough.

6 + 4 + 4 + 5 + 5 + 7
# Out:
# 31

# %%
# Now getting the sounds. 
# Importing necessary packages
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
import tensorflow as tf
import librosa
from IPython.display import Audio
import random
import soundfile as sf
import pyrubberband
# Out:
# 2022-02-04 12:49:52.613799: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-02-04 12:49:52.613879: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# Now we need a long audio file that will contain all the words distinctly. 

# Let's do a fine cropping program based on amplitude. 

# Importing the audio.
ar, sr = librosa.load('data/system_3/dub_total.wav')

# Speed shifting
# ar = pyrubberband.pyrb.time_stretch(ar, sr, 1.2, rbargs=None)

print(ar.shape)
print(sr)

Audio(data=ar, rate=sr)
# Out:
# (561152,)
# 22050
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
intervals = librosa.effects.split(ar, top_db=16)
print(intervals)
print(len(intervals))

all_words = np.array([])

# Creating arrays for each words
for i in range(len(intervals)):
    inst_interval = intervals[i]
    inst_audio = ar[inst_interval[0] : inst_interval[1]]
    
    # An extra truncation layer is needed for consonants recordings as it should be just a small part of the 
    # pronunciation.
#     if i >= 0:
#     inst_audio = inst_audio[0:2812]
    
    # Only use this when you are saving audio clips.
    sf.write('data/system_3/words/{}.wav'.format(i+0), inst_audio, sr, 'PCM_24')

    # Concatinating each words.
    all_words = np.concatenate([all_words, inst_audio])

Audio(all_words, rate=sr)
# Out:
# [[  7168  16384]
#  [ 23552  32768]
#  [ 40960  50176]
#  [ 57344  65536]
#  [ 73728  82432]
#  [ 90624  99328]
#  [108032 116736]
#  [127488 135680]
#  [143872 153600]
#  [160768 171008]
#  [181248 190464]
#  [198656 208896]
#  [216576 227840]
#  [233984 246272]
#  [256512 265216]
#  [274944 282624]
#  [291328 300544]
#  [308736 319488]
#  [326656 336384]
#  [346624 355328]
#  [366080 373760]
#  [382464 391680]
#  [400896 411136]
#  [419328 427520]
#  [436736 445952]
#  [455168 464896]
#  [472576 482304]
#  [491008 500224]
#  [510464 518144]
#  [526848 537088]
#  [546304 553472]]
# 31
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Now we have all the recording saved.
# Now we need to create some index for the vocabulary.

# a aa i u e o 
# k kh g gh 
# ch chh j jh 
# t th d dh n
# p ph b bh m
# y r l w s sh h

syllable_index_dict = {
    'a': 0,
    'aa': 1,
    'i': 2,
    'u': 3,
    'e': 4,
    'o': 5,
    'k': 6,
    'kh': 7,
    'g': 8,
    'gh': 9,
    'ch': 10,
    'chh': 11,
    'j': 12,
    'jh': 13,
    't': 14,
    'th': 15,
    'd': 16,
    'dh': 17,
    'n': 18,
    'p': 19,
    'ph': 20,
    'b': 21,
    'bh': 22,
    'm': 23,
    'y': 24,
    'r': 25,
    'l': 26,
    'w': 27,
    's': 28,
    'sh': 29,
    'h': 30,
}

# Now we have our word_index dict ready.

# %%
# Let's import all of our recordings. 
file_list = os.listdir('data/system_3/words')
print(len(file_list))
print(file_list)
# Out:
# 31
# ['25.wav', '20.wav', '8.wav', '4.wav', '3.wav', '0.wav', '13.wav', '28.wav', '23.wav', '15.wav', '17.wav', '6.wav', '19.wav', '22.wav', '24.wav', '30.wav', '16.wav', '1.wav', '2.wav', '12.wav', '29.wav', '26.wav', '18.wav', '10.wav', '27.wav', '11.wav', '7.wav', '14.wav', '9.wav', '21.wav', '5.wav']

# %%
index_ar_dict = {}

for file_name in file_list:
    inst_arr, inst_sr = librosa.load('data/system_3/words/{}'.format(file_name))
    index_ar_dict[file_name.split('.')[0]] = inst_arr
    
display(index_ar_dict)
# Out:
# {'25': array([ 0.00054932, -0.00733948, -0.00453186, ...,  0.02391052,
#          0.02256775,  0.01951599], dtype=float32),
#  '20': array([ 0.00793457,  0.02590942, -0.01716614, ..., -0.05064392,
#         -0.05708313, -0.06159973], dtype=float32),
#  '8': array([ 0.00907898,  0.00801086,  0.01144409, ..., -0.05360413,
#         -0.05360413, -0.05569458], dtype=float32),
#  '4': array([0.05088806, 0.05516052, 0.05532837, ..., 0.02481079, 0.02516174,
#         0.02536011], dtype=float32),
#  '3': array([-0.0572052 , -0.04949951, -0.04910278, ..., -0.02883911,
#         -0.03395081, -0.03649902], dtype=float32),
#  '0': array([ 0.01263428,  0.01332092,  0.01647949, ..., -0.04389954,
#         -0.04193115, -0.0324707 ], dtype=float32),
#  '13': array([-0.04307556, -0.04544067, -0.04415894, ...,  0.04327393,
#          0.04627991,  0.0401001 ], dtype=float32),
#  '28': array([ 0.0271759 , -0.00617981, -0.00086975, ...,  0.02778625,
#          0.03256226,  0.03738403], dtype=float32),
#  '23': array([ 0.0005188 ,  0.00108337,  0.00209045, ..., -0.01237488,
#         -0.01771545, -0.020401  ], dtype=float32),
#  '15': array([ 0.03404236,  0.02929688,  0.00587463, ..., -0.04592896,
#         -0.04524231, -0.04205322], dtype=float32),
#  '17': array([-0.03457642, -0.03068542, -0.02297974, ...,  0.02323914,
#          0.01991272,  0.01356506], dtype=float32),
#  '6': array([-0.04223633, -0.04432678, -0.0431366 , ..., -0.03152466,
#         -0.03201294, -0.03503418], dtype=float32),
#  '19': array([-0.01979065, -0.01773071, -0.01783752, ..., -0.01596069,
#         -0.01402283, -0.01722717], dtype=float32),
#  '22': array([-0.02520752, -0.02833557, -0.03305054, ..., -0.00506592,
#         -0.00958252, -0.01283264], dtype=float32),
#  '24': array([-0.0201416 , -0.01008606, -0.01821899, ...,  0.00267029,
#          0.01165771,  0.01695251], dtype=float32),
#  '30': array([ 0.05891418,  0.0350647 , -0.00245667, ..., -0.10023499,
#         -0.10379028, -0.10691833], dtype=float32),
#  '16': array([-0.05960083, -0.05064392, -0.02526855, ..., -0.00109863,
#         -0.01017761, -0.00976562], dtype=float32),
#  '1': array([-0.01296997, -0.01759338, -0.01435852, ...,  0.07341003,
#          0.06567383,  0.05555725], dtype=float32),
#  '2': array([-0.03201294, -0.03067017, -0.0337677 , ..., -0.02500916,
#         -0.02630615, -0.02841187], dtype=float32),
#  '12': array([-0.05703735, -0.0483551 , -0.03210449, ...,  0.01036072,
#          0.00872803,  0.00550842], dtype=float32),
#  '29': array([0.05427551, 0.01071167, 0.00050354, ..., 0.00648499, 0.00489807,
#         0.00852966], dtype=float32),
#  '26': array([0.01774597, 0.01602173, 0.01745605, ..., 0.11331177, 0.11663818,
#         0.11390686], dtype=float32),
#  '18': array([ 0.03596497,  0.0368042 ,  0.03538513, ..., -0.02412415,
#         -0.02339172, -0.02288818], dtype=float32),
#  '10': array([-0.02145386,  0.02304077,  0.04716492, ..., -0.01385498,
#         -0.00846863, -0.00254822], dtype=float32),
#  '27': array([ 0.0030365 ,  0.00688171,  0.00975037, ..., -0.01861572,
#         -0.02098083, -0.01332092], dtype=float32),
#  '11': array([0.07330322, 0.08229065, 0.06509399, ..., 0.01405334, 0.01789856,
#         0.0171051 ], dtype=float32),
#  '7': array([ 0.03710938,  0.01924133, -0.00697327, ..., -0.01652527,
#         -0.0091095 , -0.00238037], dtype=float32),
#  '14': array([-0.02365112, -0.01794434, -0.01063538, ..., -0.03097534,
#         -0.02146912, -0.01905823], dtype=float32),
#  '9': array([ 0.02987671,  0.03320312,  0.03349304, ..., -0.00823975,
#         -0.00143433, -0.00035095], dtype=float32),
#  '21': array([-0.03839111, -0.03448486, -0.03393555, ..., -0.00881958,
#         -0.01104736, -0.00994873], dtype=float32),
#  '5': array([0.02723694, 0.02374268, 0.02345276, ..., 0.02911377, 0.02713013,
#         0.01785278], dtype=float32)}

# %%
# Let's play a file from the dict
word = index_ar_dict['12']
Audio(word, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %%time
# Let's construct some sentences
# sentence = 'hamare lon seva me ap _ ka swagat hae . . ' \
# 'd m i faeneans se jankari ke liye _ ek _ dabaen . . ' + \
# 'grahak seva pratinidhi me swagat hae . . ' + \
# 'd m i faeneans se _ lon ke liye _ do _ dabaen . ' + \
# 'pratinidhi sambandhit '

# ankush
sentence = 'a n k u sh'



sentence_ar = sentence.split(' ')
print(sentence_ar)

numeric_ar = []

for word in sentence_ar:
    inst_number = syllable_index_dict[word]
    numeric_ar.append(str(inst_number))
    
print(numeric_ar)
# Out:
# ['a', 'n', 'k', 'u', 'sh']
# ['0', '18', '6', '3', '29']
# CPU times: user 548 µs, sys: 195 µs, total: 743 µs
# Wall time: 538 µs

# %%
# %%time
# Re-assembling the words.
final_voice = np.array([])

for number in numeric_ar:
    inst_audio_ar = index_ar_dict[number]
    final_voice = np.concatenate([final_voice, inst_audio_ar])


# Speed shifting
# final_voice = pyrubberband.pyrb.time_stretch(final_voice, sr, 1.0, rbargs=None)

# # Pitch shifting
# final_voice = pyrubberband.pyrb.pitch_shift(final_voice, sr, 1, rbargs=None)

# # Volume shifting
# final_voice = final_voice - 0
    
# Write the final audio.
sf.write('output_{}.wav'.format(str(1)), final_voice, sr, 'PCM_24')

Audio(final_voice, rate=sr)
# Out:
# CPU times: user 5.52 ms, sys: 524 µs, total: 6.04 ms
# Wall time: 7.4 ms
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# What are some things to be achieved to get the right pronunciation.

# We need very truncated Byanjana Varna.
# We need persistent Swara Varna.
# We need to implement Yuktakshyar.
